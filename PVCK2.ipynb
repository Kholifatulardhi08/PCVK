# %% [markdown]
# <a href="https://colab.research.google.com/github/Kholifatulardhi08/PCVK-01/blob/main/PVCK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# upload file yang sudah diunduh
# file akan disimpan sesuai dengan nama file yang diunggah
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-9d46e754-e599-4089-bc17-6056ecbfe8cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d46e754-e599-4089-bc17-6056ecbfe8cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images2.jpg to images2.jpg

# %%
# memanggil library opencv
import cv2

# memanggil fungsi google colab untuk perbaikan cv2.imshow
from google.colab.patches import cv2_imshow

# menyimpan gambar dengan fungsi imread dari OpenCV
img = cv2.imread("images2.jpg")  
# sesuaikan dengan nama file yang diunggah pada cell sebelumnya

# menampilkan gambar dengan fungsi cv2_imshow
cv2_imshow(img)

# lihat tipe data img. disimpan sebagai apa?
print(type(img))
# Out:
# <PIL.Image.Image image mode=RGB size=660x400 at 0x7F6CB1A2DBD0>
# <class 'numpy.ndarray'>

# %%
img_gray = cv.imread ('images2.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray , cmap='RdYlGn')

# %%
img_gray = cv.imread ('images2.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray , cmap='GnBu')

# %%
img = cv.flip (cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img)

# %%
cv.rectangle(img_gray, pt1=(800,400),pt2=(1000,300),color=(0,255,0),thickness=10)
cv.circle(img_gray, center=(800,600),radius=50,color=(255,0,0),thickness=8)
plt.imshow(img_gray)

# %%
cv.rectangle(img, pt1=(10,750),pt2=(200,600),color=(255,255,255),thickness=10)
plt.imshow(img)
